# %%
import random

try :

    print('_' * 45 + " 🔩🔩🔩🔩    📄📄📄📄    ✂️✂️✂️✂️ "+ '_' * 45)
    print('\n\t' + '_' * 38 + " ✍️ Prepared by Rayyan Ahmed ✍️ "+ '_' * 38)
    print('\n\t\t   ' + '_' * 30 + ' 🐍💻 Python 3.11.5 🐍💻 ' + '_' * 30 + '\t\t\t')
    print('\n\t\t\t      ' + '_' * 24 + " 👱‍♂️   vs   🤖 "+ '_' * 24)
    
    pass_ = 'Free Palestine'
    password = str(input('Enter Password: '))

    if pass_ == password:
        
        print('\n\n ✅🔓 Access Granted!')
        name = input('\nEnter your name: ')
        tries = int(input('How many tries would you like to get?: '))
        print(f'\n 🚨🚨 Mr. {name}! Now you are playing against Python3 program.Score more than program to win the game.')
        print('\n 🚨🚨 Note: Guess except Rock, Paper or Scissor will result in increasing program\'s score by 1.')
        try_ = 0
        y_score = 0 #your score
        p_score = 0 #program score
        a = '\n🏆🏆 Attempt won.'
        b = '\n⚖️⚖️ Attempt draw.'
        c = '\n❌❌ Attempt lost.'
        d = '\n⚠️⚠️ Invalid Guess! Program got 1 score due to your invalid input.'

        while try_ != tries :

            list_ = ['Rock','Paper','Scissor']
            ans = random.choice(list_)
            print(list_)

            guess = input('\n===>>Enter your guess: ')
            try_ += 1
            print(f'\nYour Guess: {guess}.')
            print(f'Program\'s Guess: {ans}.')

            if ans == 'Rock' :

                if guess == 'Rock' :
                    print(b)
                    y_score += 0
                    p_score += 0

                elif guess == 'Scissor' :
                    print(c)
                    y_score += 0
                    p_score += 1

                elif guess == 'Paper' :
                    print(c)
                    y_score += 0
                    p_score += 1

                else :
                    print(d)
                    p_score += 1

            elif ans == 'Scissor' :

                if guess == 'Rock' :
                    print(a)
                    y_score += 1
                    p_score += 0

                elif guess == 'Scissor' :
                    print(b)
                    y_score += 0
                    p_score += 0

                elif guess == 'Paper' :
                    print(c)
                    y_score += 0
                    p_score += 1  

                else :
                    print(d)
                    p_score += 1

            elif ans == 'Paper' :

                if guess == 'Rock' :
                    print(a)
                    y_score += 1
                    p_score += 0

                elif guess == 'Scissor' :
                    print(a)
                    y_score += 1
                    p_score += 0

                elif guess == 'Paper' :
                    print(b)
                    y_score += 0
                    p_score += 0

                else :
                    print(d)
                    p_score += 1

        print(f'\n{tries} tries comleted!')
        print(f' 📋 📋 Score Card:\n\n 👱‍♂️👱‍♂️ Your Score: {y_score}.\n 🤖🤖 Program\'s Score: {p_score}.')

        if y_score > p_score :
            print(f'\n 🎉🎉 Congratulations {name}! You won the match.')
        elif p_score == y_score :
            print(f'\n⚖️⚖️ Mr. {name}! The match has been draw between you and program.')
        else :
            print(f' 😔😔 Sorry {name}! You couldn\'t pass this game.You can play it again.')
            
    else:
        print("Incorrect Password!\nAccess Denied.")

except :
    print('\n⚠️⚠️Enter valid input.')
# Out:
# _____________________________________________ 🔩🔩🔩🔩    📄📄📄📄    ✂️✂️✂️✂️ _____________________________________________
#
# 	______________________________________ ✍️ Prepared by Rayyan Ahmed ✍️ ______________________________________
#
# 		   ______________________________ 🐍💻 Python 3.11.5 🐍💻 ______________________________
#
# 			      ________________________ 👱‍♂️   vs   🤖 ________________________
# Enter Password: Free Palestine
#
#
#  ✅🔓 Access Granted!
#
# Enter your name: Rayyan Ahmed
# How many tries would you like to get?: 5
#
#  🚨🚨 Mr. Rayyan Ahmed! Now you are playing against Python3 program.Score more than program to win the game.
#
#  🚨🚨 Note: Guess except Rock, Paper or Scissor will result in increasing program's score by 1.
# ['Rock', 'Paper', 'Scissor']
#
# ===>>Enter your guess: Rock
#
# Your Guess: Rock.
# Program's Guess: Rock.
#
# ⚖️⚖️ Attempt draw.
# ['Rock', 'Paper', 'Scissor']
#
# ===>>Enter your guess: Rock
#
# Your Guess: Rock.
# Program's Guess: Paper.
#
# ...
